# %% [markdown]
# class Critter(object):
#     def __init__(self, name, hunger=0, boredom=0, food=0, play=0):
#         self.name=name
#         self.hunger=hunger
#         self.boredom=boredom
#         self.food=food
#         self.play=play
#     def __pass_time(self):
#         self.hunger +=1
#         self.boredom +=1
#         print self.hunger
#         print self.boredom
#     def __get_mood(self):
#         unhappiness=self.hunger+self.boredom
#         if unhappiness <5:
#             mood="happy"
#         elif 5<=unhappiness<=10:
#             mood="okay"
#         elif 11<=unhappiness<=15:
#             mood="frustrated"
#         else:
#             mood="mad"
#         return mood
#     mood=property(__get_mood)
#     def talk(self):
#         print "I'm", self.name, "and I feel", self.mood, "now.\n"
#         self.__pass_time()
#     def eat(self):
#         self.food=0
#         while self.food not in range (1,10):
#             self.food=int(raw_input("How much food would you like to give your pet? (1-10): "))
#         print "Thank you."
#         self.hunger -= self.food
#         if self.hunger<0:
#             self.hunger=0
#         self.__pass_time()
#     def play(self):
#         self.play=0
#         while self.play not in range (1,10):
#             self.play=int(raw_input("How long would you like to play with your pet? (1-10): "))
#         print "Thank you."
#         self.boredom -=fun
#         if self.boredom <0:
#             self.boredom=0
#         self.__pass_time()
# def main():
#     crit_name=raw_input("What do you want to name your critter?:  ")
#     crit=Critter(crit_name)
#     choice=None
#     while choice!="0":
#         print \
#         """
#         Critter Caretaker
#         0 - Quit
#         1 - Listen to your critter
#         2 - Feed your critter
#         3 - Play with your critter
#         """
#         choice=raw_input("Choice: ")
#         #exit
#         if choice == "0":
#             print "Bye"
#         #listen to your critter
#         elif choice == "1":
#             crit.talk()
#         #feed your critter
#         elif choice == "2":
#             crit.eat()
#         elif choice == "3":
#             crit.play()
#         #some unknown choice
#         else:
#              print "\nSorry, but", choice, "isn't a valid choice."
# main()

# %%
class Critter(object):
    def __init__(self, name, hunger=0, boredom=0, food=0, fun=0):
        self.name=name
        self.hunger=hunger
        self.boredom=boredom
        self.food=food
        self.fun=fun
    def __str__(self):
        return "Hi, I'm " +self.__name+ " and I feel " self.__mood + "."
    def __pass_time(self):
        self.hunger +=1
        self.boredom +=1
        print self.hunger
        print self.boredom
    def __get_mood(self):
        unhappiness=self.hunger+self.boredom
        if unhappiness <5:
            mood="happy"
        elif 5<=unhappiness<=10:
            mood="okay"
        elif 11<=unhappiness<=15:
            mood="frustrated"
        else:
            mood="mad"
        return mood
    mood=property(__get_mood)
    def talk(self):
        print "I'm", self.name, "and I feel", self.mood, "now.\n"
        self.__pass_time()
    def eat(self):
        self.food=0
        while self.food not in range (1,8):
            self.food=int(raw_input("How much food would you like to give your pet? (1-7): "))
        print "Thank you."
        self.hunger -= self.food
        if self.hunger<0:
            self.hunger=0
        self.__pass_time()
    def play(self):
        self.fun=0
        while self.fun not in range (1,8):
            self.fun=int(raw_input("How long would you like to play with your pet?  (1-7): "))
        print "Thank you."
        self.boredom -=self.fun
        if self.boredom <0:
            self.boredom=0
        self.__pass_time()
def main():
    crit_name=raw_input("What do you want to name your critter?:  ")
    crit=Critter(crit_name)
    crit1=Critter(crit_name)
    choice=None
    while choice!="0":
        print \
        """
        Critter Caretaker
        0 - Quit
        1 - Listen to your critter         
        2 - Feed your critter
        3 - Play with your critter
        """
        choice=raw_input("Choice: ")
        #exit
        if choice == "0":
            print "Bye"
        #listen to your critter
        elif choice == "1":
            crit.talk()
        #feed your critter
        elif choice == "2":
            crit.eat()
        elif choice == "3":
            crit.play()
        #some unknown choice
        else:
             print "\nSorry, but", choice, "isn't a valid choice."
main()
# Out:
# What do you want to name your critter?:  Justin
#
#         Critter Caretaker
#         0 - Quit
#         1 - Listen to your critter
#         2 - Feed your critter
#         3 - Play with your critter
#
# Choice: 1
# I'm Justin and I feel happy now.
#
# 1
# 1
#
#         Critter Caretaker
#         0 - Quit
#         1 - Listen to your critter
#         2 - Feed your critter
#         3 - Play with your critter
